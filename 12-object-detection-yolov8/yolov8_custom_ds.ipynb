# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
model = YOLO('yolov8n.pt')

# %%
model.train(data='dataset/data.yaml', epochs=50, imgsz=640, batch=16, project='results', device='cpu')
# Out:
# New https://pypi.org/project/ultralytics/8.3.177 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.11.0 torch-2.2.2 CPU (Intel Core(TM) i7-9750H 2.60GHz)
# ...

# %%
model = YOLO('results/train/weights/best.pt')
results = model.predict(source='data/val/images/', imgsz=640, conf=0.25, device='cpu')
# Out:
# image 1/14 /Users/amal.basit/Desktop/Internship/12-object-detection-yolov8/data/val/images/22d_f_125.jpg: 384x640 4 players, 110.3ms
# image 2/14 /Users/amal.basit/Desktop/Internship/12-object-detection-yolov8/data/val/images/22d_f_15_rt3.jpg: 384x640 13 players, 50.1ms
# image 3/14 /Users/amal.basit/Desktop/Internship/12-object-detection-yolov8/data/val/images/22d_f_30_22d.jpg: 384x640 12 players, 48.0ms
# image 4/14 /Users/amal.basit/Desktop/Internship/12-object-detection-yolov8/data/val/images/22d_f_80.jpg: 384x640 5 players, 48.6ms
# image 5/14 /Users/amal.basit/Desktop/Internship/12-object-detection-yolov8/data/val/images/54r_f_65.jpg: 384x640 8 players, 48.7ms
# image 6/14 /Users/amal.basit/Desktop/Internship/12-object-detection-yolov8/data/val/images/6ty_f_195_6ty.jpg: 384x640 16 players, 49.5ms
# image 7/14 /Users/amal.basit/Desktop/Internship/12-object-detection-yolov8/data/val/images/6ty_f_50_we.jpg: 384x640 12 players, 1 football, 48.6ms
# ...

# %%
# Loop through each result (each image/frame)
for i, result in enumerate(results):
    # result.plot() returns an image with boxes drawn (as numpy array in BGR format)
    img_with_boxes = result.plot()

    # Convert BGR (OpenCV format) to RGB for matplotlib display
    img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)

    # Show image with bounding boxes
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(f'Detection Result {i + 1}')
    plt.show()

    # Optionally save the image with boxes
    cv2.imwrite(f'result_{i+1}.jpg', img_with_boxes)
